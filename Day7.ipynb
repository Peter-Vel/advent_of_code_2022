# %% [markdown]
# # Part One

# %%
import json
import os

# %%
file = open('./Input/Day7_Input.txt', 'r')

contents = file.read()
data = contents.split("\n")

file_structure = {
    '/': {
        'type': 'dir'
    }
}

line_ix = 1
current_dir = file_structure['/']
breadcrumb = ['/']
dir_sizes = []

# %%
def get_contents(data, ix):
    ix = ix + 1
    data_len = len(data)
    item = data[ix]
    contents = []

    while '$ cd' not in item:
        contents.append(item)
        ix = ix + 1

        if ix != data_len:
            item = data[ix]
        else:
            break

    return contents, ix

def add_contents(file_structure, current_dir, contents):
    if 'contents' not in current_dir.keys():
        current_dir['contents'] = {}

    for i in contents:
        if 'dir' in i:
            dir_name = i.split(' ')[1]
            current_dir['contents'][dir_name] = {'type': 'dir'}
        else:
            file = i.split(' ')
            name = file[1]
            size = file[0]
            current_dir['contents'][name] = {'type': 'file', 'size': size}

def change_dir(line, file_structure, current_dir, breadcrumb):
    loc = line.split(' ')[2]
    
    if loc == '..':
        breadcrumb.pop()
        current_dir = file_structure

        for c in breadcrumb:
            if c == '/':
                current_dir = current_dir[c]
            else:
                current_dir = current_dir['contents'][c]
    else:
        if loc in current_dir['contents'].keys():
            new_loc = current_dir['contents'][loc]
            current_dir = new_loc
            breadcrumb.append(loc)

    return current_dir, breadcrumb

def recurse_dict(d, dir_name, size = 0):
    dict_ct = 0
    dir_size = 0

    for k, v in d.items():        
        if (isinstance(v, dict) and len(v) != 0 
            and v['type'] == 'dir'):
            dict_ct = dict_ct + 1
        elif (isinstance(v, dict) and len(v) != 0
              and v['type'] == 'file'):
            dir_size = dir_size + int(v['size'])

    if dict_ct > 0:
        for k, v in d.items():
            if isinstance(v, dict) and len(v) != 0 and v['type'] == 'dir':
                size = recurse_dict(v['contents'], k)
                dir_size = dir_size + size
    
    dir_sizes.append(f"{dir_size} {dir_name}")
    
    return dir_size

# %%
# Build structure
while line_ix < len(data):
    line = data[line_ix]

    if line == '$ ls':
        contents, line_ix = get_contents(data, line_ix)
        add_contents(file_structure, current_dir, contents)
    elif '$ cd' in line:
        current_dir, breadcrumb = change_dir(line, file_structure, current_dir, breadcrumb)
        line_ix = line_ix + 1

# %%
# Display structure
structure_view = json.dumps(file_structure, indent=4)
print(structure_view)
# Out:
# {
#     "/": {
#         "type": "dir",
#         "contents": {
#             "dcvzbqf": {
#                 "type": "dir",
#                 "contents": {
#                     "gfvl": {
#                         "type": "dir",
#                         "contents": {
#                             "dnbmm.bgc": {
#                                 "type": "file",
#                                 "size": "104564"
#                             }
#                         }
#                     }
#                 }
#             },
#             "gsdpmrq.bsz": {
#                 "type": "file",
#                 "size": "23804"
#             },
#             "nfngbl.mcn": {
#                 "type": "file",
#                 "size": "24936"
#             },
#             "plw.frm": {
#                 "type": "file",
#                 "size": "178747"
#             },
#             "qdtw": {
#                 "type": "dir",
#                 "contents": {
#                     "fsj": {
#                         "type": "dir",
#                         "contents": {
#                             "ltbr.mdf": {
#                                 "type": "file",
#                                 "size": "118575"
#                             }
#                         }
#                     },
#                     "jwfbvmds": {
#                         "type": "dir",
#                         "contents": {
#                             "bbvg": {
#                                 "type": "dir",
#                                 "contents": {
#                                     "zbzgvsb": {
#                                         "type": "file",
#                                         "size": "219031"
#                                     },
#                                     "zhfmsb.lvv": {
#                                         "type": "file",
#                                         "size": "94339"
#                                     }
#                                 }
#                             },
#                             "bds": {
#                                 "type": "dir",
#                                 "contents": {
#                                     "hzqlb": {
#                                         "type": "file",
#                                         "size": "133483"
#                                     }
#                                 }
#                             },
#                             "clvljpb": {
#                                 "type": "dir",
#                                 "contents": {
#                                     "bmm.dwc": {
#                                         "type": "file",
#                                         "size": "103511"
#                                     },
#                                     "clvljpb.fzn": {
#                                         "type": "file",
#                                         "size": "121211"
#                                     },
#                                     "dnbmm.fmm": {
#                                         "type": "file",
#                                         "size": "158145"
#                                     },
#                                     "pcg.wnr": {
#                                         "type": "file",
#                                         "size": "74998"
#                                     },
#                                     "psvtz": {
#                                         "type": "dir",
#                                         "contents": {
#                                             "gdj": {
#                                                 "type": "dir",
#                                                 "contents": {
#                                                     "qchfgv": {
#                                                         "type": "file",
#                                                         "size": "133897"
#                                                     },
#                                                     "vmcshh": {
#                                                         "type": "dir",
#                                                         "contents": {
#                                                             "zgwwvb.pcs": {
#                                                                 "type": "file",
#                                                                 "size": "200517"
#                                                             }
#                                                         }
#                                                     },
#                                                     "zgmvb.jfg": {
#                                                         "type": "file",
#                                                         "size": "93805"
#                                                     }
#                                                 }
#                                             },
#                                             "pcgjgc.wgl": {
#                                                 "type": "file",
#                                                 "size": "167697"
#                                             },
#                                             "qchfgv": {
#                                                 "type": "file",
#                                                 "size": "2613"
#                                             },
#                                             "qsdzj.jng": {
#                                                 "type": "file",
#                                                 "size": "91712"
#                                             }
#                                         }
#                                     }
#                                 }
#                             },
#                             "gwbbbgj.hbs": {
#                                 "type": "file",
#                                 "size": "44460"
#                             },
#                             "hzqlb": {
#                                 "type": "dir",
#                                 "contents": {
#                                     "dnbmm": {
#                                         "type": "dir",
#                                         "contents": {
#                                             "msrbz.wjs": {
#                                                 "type": "file",
#                                                 "size": "223576"
#                                             }
#                                         }
#                                     }
#                                 }
#                             },
#                             "jpvnzhf": {
#                                 "type": "dir",
#                                 "contents": {
#                                     "nfngbl.mcn": {
#                                         "type": "file",
#                                         "size": "20581"
#                                     }
#                                 }
#                             },
#                             "trdm.qps": {
#                                 "type": "file",
#                                 "size": "61025"
#                             }
#                         }
#                     },
#                     "pcg.wnr": {
#                         "type": "file",
#                         "size": "216592"
#                     },
#                     "pwnhpm": {
#                         "type": "dir",
#                         "contents": {
#                             "clvljpb": {
#                                 "type": "dir",
#                                 "contents": {
#                                     "clvljpb": {
#                                         "type": "dir",
#                                         "contents": {
#                                             "hzqlb": {
#                                                 "type": "dir",
#                                                 "contents": {
#                                                     "cvgp": {
#                                                         "type": "file",
#                                                         "size": "189238"
#                                                     },
#                                                     "gjg": {
#                                                         "type": "dir",
#                                                         "contents": {
#                                                             "ttltfz.bvz": {
#                                                                 "type": "file",
#                                                                 "size": "167082"
#                                                             }
#                                                         }
#                                                     }
#                                                 }
#                                             },
#                                             "zhq": {
#                                                 "type": "dir",
#                                                 "contents": {
#                                                     "nfngbl.mcn": {
#                                                         "type": "file",
#                                                         "size": "203202"
#                                                     },
#                                                     "qhnnr.dhs": {
#                                                         "type": "file",
#                                                         "size": "212148"
#                                                     }
#                                                 }
#                                             }
#                                         }
#                                     },
#                                     "clvljpb.pls": {
#                                         "type": "file",
#                                         "size": "212906"
#                                     },
#                                     "dnm": {
#                                         "type": "file",
#                                         "size": "214564"
#                                     },
#                                     "fvgbsft": {
#                                         "type": "dir",
#                                         "contents": {
#                                             "fzhwsjf": {
#                                                 "type": "dir",
#                                                 "contents": {
#                                                     "clvljpb.png": {
#                                                         "type": "file",
#                                                         "size": "91220"
#                                                     },
#                                                     "pcg.wnr": {
#                                                         "type": "file",
#                                                         "size": "235721"
#                                                     },
#                                                     "qchfgv": {
#                                                         "type": "file",
#                                                         "size": "61559"
#                                                     },
#                                                     "vpr.nlc": {
#                                                         "type": "file",
#                                                         "size": "70762"
#                                                     }
#                                                 }
#                                             },
#                                             "nps": {
#                                                 "type": "file",
#                                                 "size": "18477"
#                                             },
#                                             "vlplrn": {
#                                                 "type": "dir",
#                                                 "contents": {
#                                                     "qrtnfmln.tpv": {
#                                                         "type": "file",
#                                                         "size": "260247"
#                                                     }
#                                                 }
#                                             },
#                                             "vnbg": {
#                                                 "type": "dir",
#                                                 "contents": {
#                                                     "ttltfz.mzr": {
#                                                         "type": "file",
#                                                         "size": "43069"
#                                                     },
#                                                     "wfb": {
#                                                         "type": "dir",
#                                                         "contents": {
#                                                             "clvljpb.mtp": {
#                                                                 "type": "file",
#                                                                 "size": "107068"
#                                                             }
#                                                         }
#                                                     },
#                                                     "zgwwvb.pcs": {
#                                                         "type": "file",
#                                                         "size": "58219"
#                                                     },
#                                                     "zhq.mrw": {
#                                                         "type": "file",
#                                                         "size": "272132"
#                                                     }
#                                                 }
#                                             },
#                                             "vpc": {
#                                                 "type": "dir",
#                                                 "contents": {
#                                                     "dnbmm.hfm": {
#                                                         "type": "file",
#                                                         "size": "185602"
#                                                     },
#                                                     "hzqlb.vtn": {
#                                                         "type": "file",
#                                                         "size": "100399"
#                                                     },
#                                                     "pcg.wnr": {
#                                                         "type": "file",
#                                                         "size": "259486"
#                                                     }
#                                                 }
#                                             }
#                                         }
#                                     },
#                                     "hzqlb.jvz": {
#                                         "type": "file",
#                                         "size": "230034"
#                                     },
#                                     "plw.frm": {
#                                         "type": "file",
#                                         "size": "48101"
#                                     },
#                                     "qchfgv": {
#                                         "type": "file",
#                                         "size": "237902"
#                                     }
#                                 }
#                             },
#                             "hzqlb.zpp": {
#                                 "type": "file",
#                                 "size": "33727"
#                             },
#                             "lfjjf.pjt": {
#                                 "type": "file",
#                                 "size": "39037"
#                             },
#                             "mbwfhq.cjj": {
#                                 "type": "file",
#                                 "size": "163662"
#                             },
#                             "nfngbl.mcn": {
#                                 "type": "file",
#                                 "size": "236292"
#                             },
#                             "zvbgnbvf": {
#                                 "type": "file",
#                                 "size": "189576"
#                             }
#                         }
#                     },
#                     "qbrpq": {
#                         "type": "dir",
#                         "contents": {
#                             "cntvzqfm.hgp": {
#                                 "type": "file",
#                                 "size": "138169"
#                             },
#                             "dnbmm.lhs": {
#                                 "type": "file",
#                                 "size": "216598"
#                             },
#                             "nfngbl.mcn": {
#                                 "type": "file",
#                                 "size": "116696"
#                             },
#                             "phf.rvn": {
#                                 "type": "file",
#                                 "size": "35315"
#                             }
#                         }
#                     },
#                     "wdc": {
#                         "type": "dir",
#                         "contents": {
#                             "ghdzdq.ghg": {
#                                 "type": "file",
#                                 "size": "270492"
#                             },
#                             "lnt.nsd": {
#                                 "type": "file",
#                                 "size": "137119"
#                             }
#                         }
#                     },
#                     "wpw": {
#                         "type": "dir",
#                         "contents": {
#                             "dnbmm": {
#                                 "type": "dir",
#                                 "contents": {
#                                     "lth.hcq": {
#                                         "type": "file",
#                                         "size": "138125"
#                                     },
#                                     "nhh.gzc": {
#                                         "type": "file",
#                                         "size": "80844"
#                                     },
#                                     "ttltfz.ntn": {
#                                         "type": "file",
#                                         "size": "149596"
#                                     }
#                                 }
#                             },
#                             "jgfv.cpp": {
#                                 "type": "file",
#                                 "size": "156266"
#                             },
#                             "lvlqcrrs.djl": {
#                                 "type": "file",
#                                 "size": "156947"
#                             },
#                             "lvznwbpg": {
#                                 "type": "dir",
#                                 "contents": {
#                                     "ldtst.dcr": {
#                                         "type": "file",
#                                         "size": "99156"
#                                     },
#                                     "pcg.wnr": {
#                                         "type": "file",
#                                         "size": "217350"
#                                     },
#                                     "plw.frm": {
#                                         "type": "file",
#                                         "size": "247238"
#                                     },
#                                     "qbqpsccr": {
#                                         "type": "dir",
#                                         "contents": {
#                                             "pcg.wnr": {
#                                                 "type": "file",
#                                                 "size": "272199"
#                                             },
#                                             "wpjqjm.qwr": {
#                                                 "type": "file",
#                                                 "size": "219600"
#                                             },
#                                             "zhq.zmq": {
#                                                 "type": "file",
#                                                 "size": "257473"
#                                             }
#                                         }
#                                     },
#                                     "wnms": {
#                                         "type": "dir",
#                                         "contents": {
#                                             "ttltfz": {
#                                                 "type": "dir",
#                                                 "contents": {
#                                                     "btm": {
#                                                         "type": "dir",
#                                                         "contents": {
#                                                             "hzqlb": {
#                                                                 "type": "dir",
#                                                                 "contents": {
#                                                                     "ttltfz": {
#                                                                         "type": "dir",
#                                                                         "contents": {
#                                                                             "hzqlb.hhm": {
#                                                                                 "type": "file",
#                                                                                 "size": "204980"
#                                                                             }
#                                                                         }
#                                                                     }
#                                                                 }
#                                                             }
#                                                         }
#                                                     }
#                                                 }
#                                             }
#                                         }
#                                     },
#                                     "zhq": {
#                                         "type": "dir",
#                                         "contents": {
#                                             "srdfz": {
#                                                 "type": "file",
#                                                 "size": "154868"
#                                             }
#                                         }
#                                     },
#                                     "zmhnzdmb.jnc": {
#                                         "type": "file",
#                                         "size": "165426"
#                                     }
#                                 }
#                             },
#                             "nfngbl.mcn": {
#                                 "type": "file",
#                                 "size": "12199"
#                             },
#                             "nlsp": {
#                                 "type": "file",
#                                 "size": "54105"
#                             },
#                             "zhq.wmz": {
#                                 "type": "file",
#                                 "size": "86737"
#                             }
#                         }
#                     },
#                     "zbfgmw": {
#                         "type": "dir",
#                         "contents": {
#                             "fcjwpgz": {
#                                 "type": "dir",
#                                 "contents": {
#                                     "jltvg": {
#                                         "type": "dir",
#                                         "contents": {
#                                             "bssvrjdq.mnr": {
#                                                 "type": "file",
#                                                 "size": "6370"
#                                             }
#                                         }
#                                     },
#                                     "qchfgv": {
#                                         "type": "file",
#                                         "size": "9958"
#                                     },
#                                     "wwqrb": {
#                                         "type": "dir",
#                                         "contents": {
#                                             "npdl": {
#                                                 "type": "file",
#                                                 "size": "157805"
#                                             },
#                                             "qchfgv": {
#                                                 "type": "file",
#                                                 "size": "237057"
#                                             },
#                                             "twrp": {
#                                                 "type": "dir",
#                                                 "contents": {
#                                                     "sfvntjwf": {
#                                                         "type": "dir",
#                                                         "contents": {
#                                                             "hdwfg.jrl": {
#                                                                 "type": "file",
#                                                                 "size": "68331"
#                                                             }
#                                                         }
#                                                     }
#                                                 }
#                                             },
#                                             "vptsgw": {
#                                                 "type": "file",
#                                                 "size": "259572"
#                                             },
#                                             "zgwwvb.pcs": {
#                                                 "type": "file",
#                                                 "size": "176388"
#                                             },
#                                             "zhq": {
#                                                 "type": "file",
#                                                 "size": "91956"
#                                             }
#                                         }
#                                     }
#                                 }
#                             },
#                             "ttltfz": {
#                                 "type": "dir",
#                                 "contents": {
#                                     "plw.frm": {
#                                         "type": "file",
#                                         "size": "41183"
#                                     }
#                                 }
#                             },
#                             "zhq": {
#                                 "type": "dir",
#                                 "contents": {
#                                     "dmzbmrdr.gtq": {
#                                         "type": "file",
#                                         "size": "32950"
#                                     },
#                                     "zhq": {
#                                         "type": "dir",
#                                         "contents": {
#                                             "dmgmwbf": {
#                                                 "type": "file",
#                                                 "size": "195502"
#                                             }
#                                         }
#                                     }
#                                 }
#                             }
#                         }
#                     }
#                 }
#             },
#             "qmfvph": {
#                 "type": "dir",
#                 "contents": {
#                     "cwfh": {
#                         "type": "dir",
#                         "contents": {
#                             "dswtm": {
#                                 "type": "dir",
#                                 "contents": {
#                                     "fmq.mrp": {
#                                         "type": "file",
#                                         "size": "70390"
#                                     },
#                                     "qjlfnlp": {
#                                         "type": "file",
#                                         "size": "108185"
#                                     },
#                                     "zhq.njc": {
#                                         "type": "file",
#                                         "size": "189923"
#                                     }
#                                 }
#                             },
#                             "mwzjf": {
#                                 "type": "dir",
#                                 "contents": {
#                                     "glmpd.mdl": {
#                                         "type": "file",
#                                         "size": "122536"
#                                     },
#                                     "nfngbl.mcn": {
#                                         "type": "file",
#                                         "size": "108226"
#                                     },
#                                     "qbvffr": {
#                                         "type": "dir",
#                                         "contents": {
#                                             "pcg.wnr": {
#                                                 "type": "file",
#                                                 "size": "147595"
#                                             }
#                                         }
#                                     },
#                                     "ttltfz": {
#                                         "type": "file",
#                                         "size": "33192"
#                                     },
#                                     "zgwwvb.pcs": {
#                                         "type": "file",
#                                         "size": "195824"
#                                     }
#                                 }
#                             }
#                         }
#                     },
#                     "dnbmm": {
#                         "type": "dir",
#                         "contents": {
#                             "cbdl": {
#                                 "type": "dir",
#                                 "contents": {
#                                     "dnrbtr.lbh": {
#                                         "type": "file",
#                                         "size": "263964"
#                                     },
#                                     "qchfgv": {
#                                         "type": "file",
#                                         "size": "66120"
#                                     },
#                                     "qwvd": {
#                                         "type": "dir",
#                                         "contents": {
#                                             "dnbmm": {
#                                                 "type": "dir",
#                                                 "contents": {
#                                                     "pcg.wnr": {
#                                                         "type": "file",
#                                                         "size": "122474"
#                                                     }
#                                                 }
#                                             },
#                                             "mhlswpcd.lpt": {
#                                                 "type": "file",
#                                                 "size": "143315"
#                                             },
#                                             "ncdrrp.ljf": {
#                                                 "type": "file",
#                                                 "size": "199969"
#                                             }
#                                         }
#                                     }
#                                 }
#                             },
#                             "fhqjzf": {
#                                 "type": "dir",
#                                 "contents": {
#                                     "fnnbrlc": {
#                                         "type": "dir",
#                                         "contents": {
#                                             "dnbmm.ngb": {
#                                                 "type": "file",
#                                                 "size": "156413"
#                                             },
#                                             "zbfnjnnz.csg": {
#                                                 "type": "file",
#                                                 "size": "30790"
#                                             }
#                                         }
#                                     },
#                                     "hzqlb": {
#                                         "type": "dir",
#                                         "contents": {
#                                             "cgzrdpr": {
#                                                 "type": "file",
#                                                 "size": "267451"
#                                             },
#                                             "nfngbl.mcn": {
#                                                 "type": "file",
#                                                 "size": "77460"
#                                             },
#                                             "plw.frm": {
#                                                 "type": "file",
#                                                 "size": "205978"
#                                             },
#                                             "sjw.ctb": {
#                                                 "type": "file",
#                                                 "size": "66224"
#                                             },
#                                             "zgwwvb.pcs": {
#                                                 "type": "file",
#                                                 "size": "212873"
#                                             }
#                                         }
#                                     },
#                                     "pcg.wnr": {
#                                         "type": "file",
#                                         "size": "254128"
#                                     },
#                                     "plw.frm": {
#                                         "type": "file",
#                                         "size": "168008"
#                                     },
#                                     "vwgvd": {
#                                         "type": "dir",
#                                         "contents": {
#                                             "phdbz.tmc": {
#                                                 "type": "file",
#                                                 "size": "161177"
#                                             }
#                                         }
#                                     },
#                                     "zhq": {
#                                         "type": "dir",
#                                         "contents": {
#                                             "hchlgv": {
#                                                 "type": "dir",
#                                                 "contents": {
#                                                     "dnbmm": {
#                                                         "type": "dir",
#                                                         "contents": {
#                                                             "pcg.wnr": {
#                                                                 "type": "file",
#                                                                 "size": "150415"
#                                                             }
#                                                         }
#                                                     },
#                                                     "hcpnwbd": {
#                                                         "type": "file",
#                                                         "size": "270943"
#                                                     },
#                                                     "hzqlb": {
#                                                         "type": "dir",
#                                                         "contents": {
#                                                             "qcvwtfg.wrl": {
#                                                                 "type": "file",
#                                                                 "size": "44475"
#                                                             }
#                                                         }
#                                                     },
#                                                     "wdljw.cgn": {
#                                                         "type": "file",
#                                                         "size": "13433"
#                                                     }
#                                                 }
#                                             },
#                                             "rfngrlz.zzr": {
#                                                 "type": "file",
#                                                 "size": "218946"
#                                             },
#                                             "zhq": {
#                                                 "type": "dir",
#                                                 "contents": {
#                                                     "ggndpjzp.rpz": {
#                                                         "type": "file",
#                                                         "size": "155076"
#                                                     }
#                                                 }
#                                             }
#                                         }
#                                     }
#                                 }
#                             },
#                             "gsgrnf.mlt": {
#                                 "type": "file",
#                                 "size": "56752"
#                             },
#                             "ndp": {
#                                 "type": "dir",
#                                 "contents": {
#                                     "nfw.htp": {
#                                         "type": "file",
#                                         "size": "112146"
#                                     },
#                                     "vqwtw.qff": {
#                                         "type": "file",
#                                         "size": "207815"
#                                     }
#                                 }
#                             },
#                             "nfngbl.mcn": {
#                                 "type": "file",
#                                 "size": "67967"
#                             },
#                             "swgwdv": {
#                                 "type": "dir",
#                                 "contents": {
#                                     "dmqn": {
#                                         "type": "dir",
#                                         "contents": {
#                                             "gdplrzt.wzf": {
#                                                 "type": "file",
#                                                 "size": "258693"
#                                             },
#                                             "hzqlb": {
#                                                 "type": "file",
#                                                 "size": "141489"
#                                             },
#                                             "pghz.brw": {
#                                                 "type": "file",
#                                                 "size": "225488"
#                                             }
#                                         }
#                                     },
#                                     "fzgdjp": {
#                                         "type": "dir",
#                                         "contents": {
#                                             "msthjppp": {
#                                                 "type": "file",
#                                                 "size": "206026"
#                                             }
#                                         }
#                                     },
#                                     "hzqlb.vtm": {
#                                         "type": "file",
#                                         "size": "205897"
#                                     },
#                                     "nfngbl.mcn": {
#                                         "type": "file",
#                                         "size": "226944"
#                                     },
#                                     "nrfpz.vmn": {
#                                         "type": "file",
#                                         "size": "259443"
#                                     },
#                                     "zgwwvb.pcs": {
#                                         "type": "file",
#                                         "size": "136591"
#                                     }
#                                 }
#                             }
#                         }
#                     },
#                     "mmmdpth": {
#                         "type": "dir",
#                         "contents": {
#                             "clvljpb": {
#                                 "type": "dir",
#                                 "contents": {
#                                     "qhgndmj": {
#                                         "type": "file",
#                                         "size": "168342"
#                                     }
#                                 }
#                             },
#                             "hzqlb": {
#                                 "type": "dir",
#                                 "contents": {
#                                     "lqvgqhw": {
#                                         "type": "dir",
#                                         "contents": {
#                                             "swnjhbj.cqt": {
#                                                 "type": "file",
#                                                 "size": "218324"
#                                             }
#                                         }
#                                     }
#                                 }
#                             },
#                             "pcg.wnr": {
#                                 "type": "file",
#                                 "size": "263747"
#                             }
#                         }
#                     },
#                     "pcg.wnr": {
#                         "type": "file",
#                         "size": "4841"
#                     },
#                     "prnpbn": {
#                         "type": "dir",
#                         "contents": {
#                             "dndnhn": {
#                                 "type": "dir",
#                                 "contents": {
#                                     "dhvvnqpt": {
#                                         "type": "file",
#                                         "size": "235760"
#                                     },
#                                     "hvg": {
#                                         "type": "dir",
#                                         "contents": {
#                                             "zqbj": {
#                                                 "type": "file",
#                                                 "size": "167698"
#                                             }
#                                         }
#                                     },
#                                     "jqvmzg": {
#                                         "type": "dir",
#                                         "contents": {
#                                             "wppv.mqz": {
#                                                 "type": "file",
#                                                 "size": "218904"
#                                             },
#                                             "zlp": {
#                                                 "type": "dir",
#                                                 "contents": {
#                                                     "wvj.gld": {
#                                                         "type": "file",
#                                                         "size": "8030"
#                                                     }
#                                                 }
#                                             }
#                                         }
#                                     },
#                                     "mhz": {
#                                         "type": "dir",
#                                         "contents": {
#                                             "tdfvwqlj": {
#                                                 "type": "file",
#                                                 "size": "37541"
#                                             }
#                                         }
#                                     }
#                                 }
#                             },
#                             "gzhtvt": {
#                                 "type": "file",
#                                 "size": "176959"
#                             },
#                             "hzqlb.clg": {
#                                 "type": "file",
#                                 "size": "85765"
#                             },
#                             "nfngbl.mcn": {
#                                 "type": "file",
#                                 "size": "120691"
#                             },
#                             "qchfgv": {
#                                 "type": "file",
#                                 "size": "245942"
#                             },
#                             "zgwwvb.pcs": {
#                                 "type": "file",
#                                 "size": "43951"
#                             }
#                         }
#                     },
#                     "sgmg.hbs": {
#                         "type": "file",
# ...
#                                         "contents": {
#                                             "clvljpb": {
#                                                 "type": "file",
#                                                 "size": "147979"
#                                             },
#                                             "dvm": {
#                                                 "type": "dir",
#                                                 "contents": {
#                                                     "cpsqlvbl": {
#                                                         "type": "dir",
#                                                         "contents": {
#                                                             "hzqlb": {
#                                                                 "type": "dir",
#                                                                 "contents": {
#                                                                     "nscj": {
#                                                                         "type": "file",
#                                                                         "size": "169253"
#                                                                     }
#                                                                 }
#                                                             }
#                                                         }
#                                                     },
#                                                     "ffw": {
#                                                         "type": "dir",
#                                                         "contents": {
#                                                             "bpg.rsw": {
#                                                                 "type": "file",
#                                                                 "size": "161525"
#                                                             },
#                                                             "dnbmm.qff": {
#                                                                 "type": "file",
#                                                                 "size": "50629"
#                                                             },
#                                                             "pcg.wnr": {
#                                                                 "type": "file",
#                                                                 "size": "126458"
#                                                             },
#                                                             "trvcmp": {
#                                                                 "type": "file",
#                                                                 "size": "18268"
#                                                             },
#                                                             "vwnlb": {
#                                                                 "type": "dir",
#                                                                 "contents": {
#                                                                     "ccjz.qrm": {
#                                                                         "type": "file",
#                                                                         "size": "218994"
#                                                                     },
#                                                                     "srwv": {
#                                                                         "type": "file",
#                                                                         "size": "268399"
#                                                                     }
#                                                                 }
#                                                             },
#                                                             "zgwwvb.pcs": {
#                                                                 "type": "file",
#                                                                 "size": "171750"
#                                                             },
#                                                             "zhq": {
#                                                                 "type": "dir",
#                                                                 "contents": {
#                                                                     "ztcw.dlc": {
#                                                                         "type": "file",
#                                                                         "size": "150894"
#                                                                     }
#                                                                 }
#                                                             }
#                                                         }
#                                                     },
#                                                     "hzqlb": {
#                                                         "type": "dir",
#                                                         "contents": {
#                                                             "fnb.vgg": {
#                                                                 "type": "file",
#                                                                 "size": "45224"
#                                                             },
#                                                             "nfngbl.mcn": {
#                                                                 "type": "file",
#                                                                 "size": "53728"
#                                                             },
#                                                             "zhq.bsw": {
#                                                                 "type": "file",
#                                                                 "size": "230460"
#                                                             }
#                                                         }
#                                                     },
#                                                     "pcg.wnr": {
#                                                         "type": "file",
#                                                         "size": "95516"
#                                                     },
#                                                     "tcswqq.zjf": {
#                                                         "type": "file",
#                                                         "size": "60101"
#                                                     }
#                                                 }
#                                             },
#                                             "pcg.wnr": {
#                                                 "type": "file",
#                                                 "size": "136916"
#                                             },
#                                             "rwnrfrph": {
#                                                 "type": "file",
#                                                 "size": "205323"
#                                             }
#                                         }
#                                     },
#                                     "zqgcbnrt": {
#                                         "type": "dir",
#                                         "contents": {
#                                             "bdjbn": {
#                                                 "type": "file",
#                                                 "size": "91447"
#                                             }
#                                         }
#                                     }
#                                 }
#                             },
#                             "wbvcf": {
#                                 "type": "dir",
#                                 "contents": {
#                                     "dzh": {
#                                         "type": "dir",
#                                         "contents": {
#                                             "qrvn.bft": {
#                                                 "type": "file",
#                                                 "size": "250311"
#                                             }
#                                         }
#                                     }
#                                 }
#                             },
#                             "wsqvpp": {
#                                 "type": "dir",
#                                 "contents": {
#                                     "jwhtlzcm.gmq": {
#                                         "type": "file",
#                                         "size": "96530"
#                                     }
#                                 }
#                             },
#                             "zgwwvb.pcs": {
#                                 "type": "file",
#                                 "size": "148645"
#                             }
#                         }
#                     },
#                     "ttltfz.mjc": {
#                         "type": "file",
#                         "size": "178296"
#                     },
#                     "zcvfqn": {
#                         "type": "dir",
#                         "contents": {
#                             "hzqlb.jfp": {
#                                 "type": "file",
#                                 "size": "264037"
#                             },
#                             "nlnl": {
#                                 "type": "dir",
#                                 "contents": {
#                                     "nfngbl.mcn": {
#                                         "type": "file",
#                                         "size": "248407"
#                                     },
#                                     "pzwmrfht.dfs": {
#                                         "type": "file",
#                                         "size": "188078"
#                                     },
#                                     "qchfgv": {
#                                         "type": "file",
#                                         "size": "268160"
#                                     }
#                                 }
#                             },
#                             "qchfgv": {
#                                 "type": "file",
#                                 "size": "96691"
#                             },
#                             "zhq.ndc": {
#                                 "type": "file",
#                                 "size": "126674"
#                             }
#                         }
#                     },
#                     "zhq": {
#                         "type": "dir",
#                         "contents": {
#                             "bgc.grv": {
#                                 "type": "file",
#                                 "size": "91941"
#                             }
#                         }
#                     },
#                     "zhq.pjm": {
#                         "type": "file",
#                         "size": "32446"
#                     },
#                     "zpb": {
#                         "type": "dir",
#                         "contents": {
#                             "dnbmm": {
#                                 "type": "dir",
#                                 "contents": {
#                                     "lcpg": {
#                                         "type": "file",
#                                         "size": "260358"
#                                     },
#                                     "lfm": {
#                                         "type": "dir",
#                                         "contents": {
#                                             "qchfgv": {
#                                                 "type": "file",
#                                                 "size": "227028"
#                                             }
#                                         }
#                                     }
#                                 }
#                             },
#                             "fsw": {
#                                 "type": "dir",
#                                 "contents": {
#                                     "fffpsrvp": {
#                                         "type": "dir",
#                                         "contents": {
#                                             "gflwnfc": {
#                                                 "type": "dir",
#                                                 "contents": {
#                                                     "cjznqwf.hhq": {
#                                                         "type": "file",
#                                                         "size": "132820"
#                                                     },
#                                                     "nfngbl.mcn": {
#                                                         "type": "file",
#                                                         "size": "224464"
#                                                     },
#                                                     "qchfgv": {
#                                                         "type": "file",
#                                                         "size": "104803"
#                                                     }
#                                                 }
#                                             },
#                                             "lwz.pgq": {
#                                                 "type": "file",
#                                                 "size": "176446"
#                                             }
#                                         }
#                                     },
#                                     "pcg.wnr": {
#                                         "type": "file",
#                                         "size": "153630"
#                                     },
#                                     "qtwvgmtl": {
#                                         "type": "dir",
#                                         "contents": {
#                                             "rcssfd": {
#                                                 "type": "dir",
#                                                 "contents": {
#                                                     "htr.chf": {
#                                                         "type": "file",
#                                                         "size": "56266"
#                                                     },
#                                                     "qcfsth.mlt": {
#                                                         "type": "file",
#                                                         "size": "128262"
#                                                     },
#                                                     "sqrb": {
#                                                         "type": "file",
#                                                         "size": "120527"
#                                                     }
#                                                 }
#                                             }
#                                         }
#                                     },
#                                     "qzl.pcn": {
#                                         "type": "file",
#                                         "size": "2971"
#                                     },
#                                     "zrpl.hcc": {
#                                         "type": "file",
#                                         "size": "17259"
#                                     }
#                                 }
#                             }
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }

# %%
# Calculate dir sizes
recurse_dict(file_structure['/']['contents'], '/')
# Out:
# 41111105

# %%
final_size = 0

# Used for part 2 #
file_system_size = 70000000
free_space_target = 30000000
###################

for i in dir_sizes:
    dir = i.split(' ')
    name = dir[1]
    size = int(dir[0])

    # Used for part 2 #
    if name == '/':
        space_used = file_system_size - size
        space_to_clear = free_space_target - space_used
    ###################

    if size <= 100000:
        final_size = final_size + size

print(f"Answer (part one) - Find any dirs with a size <= 100000 and sum all of their sizes: {final_size}")
# Out:
# Answer (part one) - Find any dirs with a size <= 100000 and sum all of their sizes: 1543140

# %% [markdown]
# # Part Two

# %%
file_system_size = 70000000
free_space_target = 30000000
final_sizes = []

print(f"Total space used: {space_used}")
print(f"Amount of space to clear = {space_to_clear}")

for i in dir_sizes:
    dir = i.split(' ')
    size = int(dir[0])

    if size >= space_to_clear:
        final_sizes.append(size)

print(f"Answer (part two) - Size of dir to delete: {min(final_sizes)}")
# Out:
# Total space used: 28888895
# Amount of space to clear = 1111105
# Answer (part two) - Size of dir to delete: 1117448
